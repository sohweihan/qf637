# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
tickers = {
    "Gold": "GC=F",          # Gold futures
    "Brent": "BZ=F",         # Brent crude futures
    "DXY": "DX-Y.NYB",       # US Dollar Index
    "VIX": "^VIX",           # CBOE Volatility Index
    "US10Y": "^TNX",         # 10Y Treasury yield, quoted as yield x 10
}

# %% [markdown]
# ### Adjust Date as preferred

# %%
start_date = "2010-01-01"
end_date = None

# %%
raw_data = yf.download(
    tickers=list(tickers.values()),
    start=start_date,
    end=end_date,
    auto_adjust=False,
    group_by="column", # or you can use group_by="ticker"
    threads=True
)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
raw_data.head()
# Out:
# Price       Adj Close                                                Close  \
# Ticker           BZ=F   DX-Y.NYB         GC=F   ^TNX       ^VIX       BZ=F
# Date
# 2010-01-04  80.120003  77.529999  1117.699951  3.841  20.040001  80.120003
# 2010-01-05  80.589996  77.620003  1118.099976  3.755  19.350000  80.589996
# 2010-01-06  81.889999  77.489998  1135.900024  3.808  19.160000  81.889999
# 2010-01-07  81.510002  77.910004  1133.099976  3.822  19.059999  81.510002
# 2010-01-08  81.370003  77.470001  1138.199951  3.808  18.129999  81.370003
#
# Price                                                 ...       Open  \
# Ticker       DX-Y.NYB         GC=F   ^TNX       ^VIX  ...       BZ=F
# Date                                                  ...
# 2010-01-04  77.529999  1117.699951  3.841  20.040001  ...  80.120003
# 2010-01-05  77.620003  1118.099976  3.755  19.350000  ...  80.589996
# 2010-01-06  77.489998  1135.900024  3.808  19.160000  ...  81.129997
# 2010-01-07  77.910004  1133.099976  3.822  19.059999  ...  81.510002
# 2010-01-08  77.470001  1138.199951  3.808  18.129999  ...  81.370003
#
# Price                                                Volume                  \
# Ticker       DX-Y.NYB         GC=F   ^TNX       ^VIX   BZ=F DX-Y.NYB   GC=F
# Date
# 2010-01-04  77.930000  1117.699951  3.859  21.680000   97.0      0.0  184.0
# 2010-01-05  77.370003  1118.099976  3.790  20.049999   97.0      0.0   53.0
# 2010-01-06  77.650002  1135.900024  3.771  19.590000    7.0      0.0  363.0
# 2010-01-07  77.370003  1133.099976  3.845  19.680000    7.0      0.0   56.0
# 2010-01-08  77.980003  1138.199951  3.843  19.270000    7.0      0.0   54.0
#
# Price
# Ticker     ^TNX ^VIX
# Date
# 2010-01-04  0.0  0.0
# 2010-01-05  0.0  0.0
# 2010-01-06  0.0  0.0
# 2010-01-07  0.0  0.0
# 2010-01-08  0.0  0.0
#
# [5 rows x 30 columns]

# %%
raw_data.to_parquet("raw_yfinance.parquet")
